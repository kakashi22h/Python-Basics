# %% [markdown]
# <a href="https://colab.research.google.com/github/kakashi22h/Python-Basics/blob/main/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Strings are sequence of Characters
#
# In python specifically, strings are a sequence of unicode characters.
#
#     - Creating Strings
#     - Accessing Strings
#     - Adding Chars to Strings
#     - Editing Strings
#     - Deleting Strings
#     - Operations on Strings
#     - Strings Functions

# %%
s = 'hello'
s = "hello"
# for multi line strings
s = '''hello'''
s = str('hello')
print(s)
# Out:
# hello

# %% [markdown]
# # Accessing Substrings from a String

# %%
# Positive Indexing
s = 'hello world'
print(s[1])
# Out:
# e

# %%
# Negative indexing
s = 'hello world'
print(s[-1])
# Out:
# d

# %%
# Slicing
s = 'hello world'
print(s[0:6:2])
# Out:
# hlo

# %%
s = 'hello world'
print(s[-5:])
# Out:
# world

# %% [markdown]
# # Editing and Deleting in String

# %%
# Python Strings are immutable
# means we can not change or delete string once string is created

# %%
del s
# it's not an actual deletion

# %% [markdown]
# # Operations in string
#     - Arithmetic Operations
#     - Relational Operations
#     - Logical Operations
#     - Loops on Strings
#     - Membership Operations

# %%
print('Delhi' + ' ' +' Mumbai')
# Out:
# DelhiMumbai

# %%
print('delhi'*5)
# Out:
# delhidelhidelhidelhidelhi

# %%
'delhi' == 'mumbai'
# Out:
# False

# %%
'mumbai' > 'pune'
# lexiographically comparesion
# Out:
# False

# %%
'Pune' > 'pune'
# Out:
# False

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
'hello' or 'world'
# Out:
# 'hello'

# %%
for i in 'hello':
  print(i)
# Out:
# h
# e
# l
# l
# o

# %%
'd' in 'delhi'
# Out:
# True

# %% [markdown]
# # String Functions
#
# # Common Functions
#     - len
#     - max
#     - min
#     - sorted

# %%
# len
len('hello Wold')
# Out:
# 10

# %%
# max
max('hello world')
# Out:
# 'w'

# %%
# min
min('hello world')
# Out:
# ' '

# %%
# sorted
sorted('hello world')
# Out:
# [' ', 'd', 'e', 'h', 'l', 'l', 'l', 'o', 'o', 'r', 'w']

# %% [markdown]
# # Capitalize/Title/Upper/Lower/Swapcase

# %%
# Capitalize
s = 'hello world'
print(s.capitalize())
# Out:
# Hello world

# %%
# Title
s = 'hello world'
s.title()
# Out:
# 'Hello World'

# %%
# Upper
s = 'hello world'
s.upper()

# Lower
s.lower()
# Out:
# 'hello world'

# %%
# swapcase
s  = 'hello world'
s.swapcase()
# Out:
# 'HELLO WORLD'

# %% [markdown]
# # Count/Find/Index

# %%
# Count
'my name is nitish.'.count('i')
# Out:
# 3

# %%
# find
'my name is nitish'.find('is')
# Out:
# 8

# %%
# index
'my name is nitish'.index('i')
# Out:
# 8

# %% [markdown]
# # endswith/startswith

# %%
# endswith
'my name is nitish'.endswith('sh')
# Out:
# True

# %%
# startswith
'my name is nitish'.startswith('my')
# Out:
# True

# %% [markdown]
# # format

# %%
name = 'hulk'
gender = 'male'

'Hi my name is {} and I am a {}'.format(name,gender)
# Out:
# 'Hi my name is hulk and I am a male'

# %% [markdown]
# # isalnum/isalpha/isdigit/isidentifier

# %%
# isalnum
'nitish123'.isalnum()
# Out:
# True

# %%
# isalpha
'nitish'.isalpha()
# Out:
# True

# %%
# isdigit
'123'.isdigit()
# Out:
# True

# %%
# isidentifier
'name1'.isidentifier()
# Out:
# True

# %% [markdown]
# #Split/Join

# %%
'hi my name is nitish'.split()
# Out:
# ['hi', 'my', 'name', 'is', 'nitish']

# %%
" ".join(['hi', 'my', 'name', 'is', 'nitish'])
# Out:
# 'hi my name is nitish'

# %% [markdown]
# # Replace

# %%
'hi my name is nitish'.replace('nitish','campusx')
# Out:
# 'hi my name is campusx'

# %% [markdown]
# #strip

# %%
'nitish               '.strip()
# Out:
# 'nitish'

# %% [markdown]
# # Questions on strings

# %%
# Find the length of a given string without using the len() function:
s = input('enter the string')

counter = 0

for i in s:
  counter += 1

print(counter)
# Out:
# enter the stringnitish
# 6

# %%
# Extract username from a given email.
#eg if the email is nitish24@gmail.com
# then the username should be nitish24

s = input('enter the email')

position = s.index('@')
print(s[0:position])
# Out:
# enter the emailnitish24@gmail.com
# nitish24

# %%
# Count the frequency of a perticular character in a provided string.
# eg 'hello how are you' is the string, the frequency of h in this string is 2.

s = input('enter the email')
term = input()

counter = 0
for i in s:
  if i == term:
    counter += 1

print(counter)
# Out:
# enter the emailhello how are you
# o
# 3

# %%
# write a program which can remove a particular character from a string
s = input('enter the email')
term = input()

result = ''

for i in s:
  if i != term:
    result = result + i

print(result)

# %%
#Write a program that can check wheter a given string is palindrome or not.
